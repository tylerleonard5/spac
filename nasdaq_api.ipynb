# %%
pip install quandl
# Out:
# Collecting quandl
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests>=2.7.0 in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (2.27.1)
# Requirement already satisfied: python-dateutil in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: pandas>=0.14 in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (1.4.2)
# Requirement already satisfied: more-itertools in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (8.13.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: numpy>=1.8 in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (1.21.5)
# Requirement already satisfied: six in c:\users\tyler\anaconda3\lib\site-packages (from quandl) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tyler\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tyler\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tyler\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tyler\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tyler\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.0.4)
# Installing collected packages: quandl
# Successfully installed quandl-3.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# %%
quandl.ApiConfig.api_key = "Kjs8Kd4EzMr5owZwTazd"

# %%
tsla = quandl.get('WIKI/TSLA', start_date = "2010-06-29", end_date = "2018-03-27")

# %%
tsla.head()
# Out:
#              Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0      19.00    25.0000     17.54       23.89
# 2010-06-30          1.0      25.79    30.4192     23.30       23.83
# 2010-07-01          1.0      25.00    25.9200     20.27       21.96
# 2010-07-02          1.0      23.00    23.1000     18.71       19.20
# 2010-07-06          1.0      20.00    20.0000     15.83       16.11
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# 2010-07-06    6866900.0
